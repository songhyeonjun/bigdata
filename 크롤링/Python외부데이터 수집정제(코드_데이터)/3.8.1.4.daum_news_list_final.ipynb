# %%
import requests
import lxml.html
import pandas as pd
import sqlite3
from pandas.io import sql
import os
import time

# %%
def db_save(NEWS_LIST):
    with sqlite3.connect(os.path.join('.','sqliteDB')) as con:
        try:
            NEWS_LIST.to_sql(name = 'NEWS_LIST', con = con, index = False, if_exists='append') 
            #if_exists : {'fail', 'replace', 'append'} default : fail
        except Exception as e:
            print(str(e))
        print(len(NEWS_LIST), '건 저장완료..')

# %%
def db_delete():
    with sqlite3.connect(os.path.join('.','sqliteDB')) as con: 
        try:
            cur = con.cursor()
            sql = 'DELETE FROM NEWS_LIST'
            cur.execute(sql)
        except Exception as e:
            print(str(e))

# %%
def db_select():
    with sqlite3.connect(os.path.join('.','sqliteDB')) as con: 
        try:
            query = 'SELECT * FROM NEWS_LIST'
            NEWS_LIST = pd.read_sql(query, con = con)
        except Exception as e:
            print(str(e)) 
        return NEWS_LIST

# %%
import re
import string

def get_detail(url):
    body = []
    punc = '[!"#$%&\'()*+,-./:;<=>?[\]^_`{|}~“”·]'
    response = requests.get(url)
    root = lxml.html.fromstring(response.content)
    for p in root.xpath('//*[@id="harmonyContainer"]/section/p'):
        if p.text: # 체크
            body.append(re.sub(punc, '', p.text)) # 특수문자 제거
    full_body = ' '.join(body)
    
    return full_body

# %%
page = 58
max_page = 0
REG_DATE = '20200819'

# %%
while(True):
    df_list = []
    response = requests.get('http://news.daum.net/breakingnews/digital?page={}&regDate={}'\
                            .format(page, REG_DATE))
    root = lxml.html.fromstring(response.content)
    for li in root.xpath('//*[@id="mArticle"]/div[3]/ul/li'):
        a = li.xpath('div/strong/a')[0]
        url = a.get('href')
        article = get_detail(url)
        df = pd.DataFrame({'URL' : [url],'TITLE':[a.text],'ARTICLE' : [article]})
        df_list.append(df)   
        
    if df_list:   
        df_10 = pd.concat(df_list)
        db_save(df_10)

    # 페이지 번호 중에서 max 페이지 가져오기    
    for a in root.xpath('//*[@id="mArticle"]/div[3]/div/span/a'):
        try:
            num = int(a.text)
            if max_page < num:
                max_page = num       
        except:
            pass

    # 마지막 페이지 여부 확인     
    span = root.xpath('//*[@id="mArticle"]/div[3]/div/span/a[@class="btn_page btn_next"]')

    if (len(span) <= 0) & (page > max_page):
        break
    else:
        page = page + 1
        
    time.sleep(1)
# Out:
# 15 건 저장완료..
# 15 건 저장완료..
# 15 건 저장완료..
# 15 건 저장완료..

# %%
# db_delete()

# %%
print(db_select())
# Out:
#                                        URL  \
# 0   https://v.daum.net/v/20200819084726268
# 1   https://v.daum.net/v/20200819084715258
# 2   https://v.daum.net/v/20200819084702255
# 3   https://v.daum.net/v/20200819084617234
# 4   https://v.daum.net/v/20200819084529215
# 5   https://v.daum.net/v/20200819084517208
# 6   https://v.daum.net/v/20200819084251134
# 7   https://v.daum.net/v/20200819083702982
# 8   https://v.daum.net/v/20200819083528956
# 9   https://v.daum.net/v/20200819083303903
# 10  https://v.daum.net/v/20200819083135880
# 11  https://v.daum.net/v/20200819082825812
# 12  https://v.daum.net/v/20200819082814806
# 13  https://v.daum.net/v/20200819082703784
# 14  https://v.daum.net/v/20200819082610764
# 15  https://v.daum.net/v/20200819082557759
# 16  https://v.daum.net/v/20200819082503742
# 17  https://v.daum.net/v/20200819082501741
# 18  https://v.daum.net/v/20200819082324702
# 19  https://v.daum.net/v/20200819081608550
# 20  https://v.daum.net/v/20200819080415266
# 21  https://v.daum.net/v/20200819080203202
# 20                            애플뮤직,  新라디오 서비스로 재도약 추진
# 21                 "우시바이오로직스, 상반기 호실적..내년 40%대 성장 회복"
# 22                        中 HKC OLED 투자 보류..코로나19에 발목
# 23               '리모컨으로 채널돌리기 그만'..LG헬로, 넷플릭스처럼 UI 개편
# 24          '최불암 시리즈'가 광고로?..게임광고에 분 '뉴트로' 바람 [Oh!덕후]
# 25              트렌드마이크로, IT환경 보안위협 탐지·대응 'XDR 플랫폼' 출시
# 26                 6가지 색 '갤럭시S20 팬에디션' 이미지 유출..10월 출시
# 27                      오리온, '초코파이情 바나나' 4년 만에 리뉴얼 출시
# 28                            이웃집 확진자에 '도로 재택' 들어간 판교
# 29               "토종 OTT '역차별' 없도록"..OTT정책협의체 내주 실무회의
# 30                         태양계 밖 외계에서 온 '오우무아무아' 정체는?
# 31              "술 취해 휘청거리는 당신, 스마트폰은 안다"..개인 음주경고 성큼
# 32                    SKT, 코로나19로 채용난 겪는 협력사 50개사 돕는다
# 33        [사이테크 플러스] 음주사고로 절친잃은 슬픔에..스마트폰으로 걸음분석 과음파악
# 34             퍼스널 트레이닝을 비대면으로? - 스포투 [혁신, 스타트업을 만나다]
# 35                         쉽게 못 풀걸?..삼성, 그림으로 휴대폰 잠근다
# 36         [과학게시판] 정병선 과기차관, 연구장비산업 경쟁력 강화방안 간담회 가져 外
# 37       '전광훈 코로나 확진' 일파만파에 설훈 "통합당이 집회 독려..대국민 사과해야"
# 38                          "내가 샀다"는 삼성 모니터 리뷰도 '뒷광고'
# 39          네이버웹툰, 북미 1위 '로어 올림푸스' 한국어 버전 19일 국내 첫 공개
# 40              韓 제약사, 코로나19 악재에도 다양한 채널 통한 R&D 투자 확대
# 41                    기로에 선 화웨이 스마트폰 사업.. 11월에 운명 갈린다
# 42               페이스북 vs 방통위 '망 품질 책임론' 2심 결과 이번주 나온다
# 43              움츠리는 메모리 시장.. 하반기 삼성⋅하이닉스 실적 우려 현실화되나
# 44                        "통행세 더 내라" 구글·애플 횡포에 앱시장 전운
# 45                      고개드는 토종 OTT 통합론..넷플릭스 대항마 나올까
# 46                  카카오페이지, 글로벌 역량 갖춘 제작사 '크로스픽쳐스' 인수
# 47                 "이태원때처럼"..기지국 정보로 광화문집회 참석자 알 수 있나
# 48                     계속되는 코로나19 돌연변이..'칵테일 항체'로 잡는다
# 49                              투명한 공원 공중화장실, 왜 만들었을까
# 50                            부산 특구는 암호화폐를 비켜가지 않습니데이
# 51                   DAXPO 2020, 코로나19 이후 새로운 금융 토론한다
# 52                   코로나19 재확산 위험 커졌다.. 여름잠 준비하는 IT업계
# 53                               LG 벨벳, 최적의 메모리 용량 제안
# 54                      5G 보급과 함께 쑥쑥.. VR게임 대중화시대 열린다
# 55                "게임에 빠진 아이와 소통하려면..'게임의 룰'부터 파악하세요"
# 56  "재택근무부터 온라인 콘서트까지..코로나19로 모바일이 삶에 뿌리내렸다"[신무경의 ...
# 57               보름 앞으로 다가온 반쪽 행사 'IFA 2020'..강행 배경은?
# 58                    방심위, 진공 청소기 흡입력 오인케한 공영쇼핑에 '주의'
# 59            [TF초점] 기대 높아진 갤노트20, 상반기 갤S20 부진까지 씻어낼까
#
#                                               ARTICLE
# 0   지디넷코리아이정현 미디어연구소테슬라와 스페이스X의 최고 경영자CEO 일론 머스크가 ...
# 1   19일 모바일 데이터 및 분석 플랫폼 앱애니에 따르면 2020년 상반기 전 세계 스...
# 2   한국에너지기술평가원은 생활방역 정착과 지역경제 활성화에 기여하기 위해 999 비말을...
# 3   지디넷코리아유효정 중국 전문기자중국 정부 주도로 다음달에서 전국 단위에서 5G 단독...
# 4   아시아경제 이진규 기자 신종 코로나바이러스감염증코로나19 확산 여파로 실내 활동이 ...
# 5   헤럴드경제구본혁 기자 약 5분 충전에 600km를 주행할 수 있는 전기차 배터리를 ...
# 6   지디넷코리아백봉삼 기자배달의민족이하 배민을 운영하는 우아한형제들은 집중호우 피해로 ...
# 7   미국 애질런트 테크놀로지스Agilent Technologies가 리보핵산 간섭RNA...
# 8   지디넷코리아안희정 기자최근 정부가 한국판 뉴딜 정책으로 디지털 뉴딜을 내세워 디지털...
# 9   코로나19 장기화에 따라 비대면 환경도 발전 중이다 오프라인 배경의 직접 소통으로 ...
# 10  아시아경제 황준호 기자 5분 충전해 600km를 주행할 수 있는 리튬금속 배터리 개...
# 11  19일 모바일 데이터 분석 플랫폼 앱애니가 발표한 ‘2020년 상반기 전세계 모바일...
# 12  지디넷코리아김한준 기자코로나19 재확산 우려에 재택근무를 시행하는 기업이 늘어나는 ...
# 13  최근 유튜브 뒷광고 논란과 함께 다수 연예인의 사과에 이어 크리에이터의 은퇴가 이어...
# 14  지디넷코리아백봉삼 기자앱 마켓의 높은 수수료도 문제지만 구글이나 애플 같은 시장 지...
# 15  지디넷코리아방은주 기자인공지능AI 기반 명품구매 플랫폼 트렌비대표 박경훈는 브랜드를...
# 16  19일 네이버 댓글 통계를 볼 수 있는 네이버 데이터랩에 따르면 지난 17일 네이버...
# 17  통합당 과방위원들은 이날 국회 과방위 전체회의실에서 단독으로 긴급현안질의를 개최 검...
# 18  서울뉴스1 이창규 기자  삼성전자의 하반기 전략 스마트폰인 갤럭시노트20이 공식 출...
# 19  LG헬로비전이 자사 케이블TV 서비스인 헬로tv의 UIUX사용자 환경경험를 전면 개...
# 20  아이뉴스24 안희권 기자 애플이 음악 스트리밍 서비스 애플뮤직의 라디오 부분을 보강...
# 21  한국투자증권은 19일 중국의 의약품 위탁생산기업CMO 우시바이오로직스의 실적이 내년...
# 22  지디넷코리아양태훈 기자중국 디스플레이 업체 HKC가 대형 유기발광다이오드 투자계획을...
# 23  서울뉴스1 강은성 기자  1번부터 시작해 보고싶은 채널을 찾기 위해 리모컨을 돌리던...
# 24  OSEN고용준 기자 뉴트로란 새로움new과 복고retro를 합친 신조어로 직접 겪어...
# 25  아이뉴스24 최은정 기자 트렌드마이크로는 전자메일과 단말서버 클라우드 및 네트워크 ...
# 26  아시아경제 한진주 기자 삼성전자의 갤럭시S20 팬 에디션이 기존에 출시되지 않았던 ...
# 27  디지털타임스 심화영 기자 오리온은 초코파이情 바나나를 겉과 속을 모두 개선해 리뉴얼...
# 28  네이버는 8월 말까지 주 5일 원격근무 체제를 유지하며 추이를 지켜보기로 했다 당초...
# 29  서울뉴스1 강은성 기자  웨이브나 티빙 등 토종 온라인동영상스트리밍서비스OTT에 들...
# 30  지금까지 관측된 천체들과는 매우 다른 특징을 가졌는데 태양계 밖 다른 행성계에서 만...
# 31  서울뉴스1 김승준 기자  술 마신 다음 날 스마트폰을 보니 기억에 없는 전화 기록이...
# 32  서울연합뉴스 채새롬 기자  SK텔레콤이 신종 코로나바이러스 감염증코로나19 여파로 ...
# 33  서울연합뉴스 이주영 기자  미국 연구팀이 스마트폰에 내장된 센서로 걸음걸이 데이터를...
# 34  스포츠경향  비대면의 시대가 열렸다 회의도 비대면으로 하고 회식도 비대면으로 하는 ...
# 35  삼성전자는 코로나19로 인해 18일 온라인으로 진행한 제4회 삼성보안기술포럼SSTF...
# 36  ■ 정병선 과학기술정보통신부 1차관은 이달 18일 대전 유성구 한국표준과학연구원과 ...
# 37  설 최고위원은 18일 전파를 탄 BBS라디오 ‘박경수의 아침저널’에 나와 통합당은 ...
# 38  미디어오늘  뒷광고 논란을 계기로 디지털 미디어 업계가 자정에 나섰지만 여전히 광고...
# 39  네이버웹툰은 ‘로어 올림푸스Lore Olympus’를 19일부터 국내에서 정식 연재...
# 40
# 41  최근 화웨이는 스마트폰에 탑재할 자체 통신칩 ‘기린’ 생산까지 포기한다고 밝혔다 미...
# 42  글로벌 기업과 정부 간 법정 다툼으로 주목을 받은 페이스북과 방송통신위원회의 행정소...
# 43
# 44  18일 업계에 따르면 구글 플레이스토어는 국내에서도 앱스토어 수수료를 고객 결제금액...
# 45                         데일리안 김은경 기자 ek@dailiancokr
# 46  크로스픽쳐스는 2003년 미국 법인 설립을 시작으로 국내에서는 드라마 ‘마음의 소리...
# 47  전광훈 목사가 있는 서울 성북구 사랑제일교회 관련 확진자가 5일 만에 457명대로 ...
# 48  앵커  전 세계가 코로나19 치료제와 백신 개발에 속도를 내고 있습니다  하지만 바...
# 49  공원에 설치된 공중화장실은 누구나 이용할 수 있는 개방 시설이지만 불특정 다수가 사...
# 50  부산광역시는 지난해 7월 국내 첫 ‘블록체인 규제자유특구’에 지정됐다 지금까지 추가...
# 51   코인데스크코리아와 한국블록체인협회가 공동주최하고 부산광역시가 후원하는 디지털자산박...
# 52  19일 업계에 따르면 코로나19가 수도권을 중심으로 확산되면서 국내 주요 IT업체가...
# 53  고용량 메모리는 No 수년 전만 해도 보고 싶은 영화를 스마트폰에 내려받아 저장하던...
# 54  18일 게임업계와 외신 보도 등에 따르면 올해 3월 판매를 시작한 미 게임사 밸브의...
# 55  방승호 서울시교육청 교육연구관59은 게임에 대한 오해가 크다고 말했다 서울 중구 충...
# 56  글로벌 앱 분석업체 앱애니는 17일미국 현지시간 ‘신종 코로나바이러스 감염증코로나1...
# 57  유럽 최대 가전ㆍ정보기술IT 전시회인 ‘IFA 2020’가 신종 코로나바이러스 감염...
# 58  지디넷코리아안희정 기자방송통신심의위원회는 19일 광고심의소위원회 회의를 열고 가정용...
# 59  더팩트│최수진 기자 신종 코로나바이러스 감염증코로나19 사태 이후 굳게 닫힌 소비자...
