# %%
import pandas as pd
import numpy as np

# %%
# 카카오API를 사용하여 주소->좌표 변환
import requests, json

def get_location(address):
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query=' + address
    # 'KaKaoAK '는 그대로 두시고 개인키만 지우고 입력해 주세요.
    # ex) KakaoAK 6af8d4826f0e56c54bc794fa8a294
    headers = {"Authorization": "KakaoAK"}
    api_json = json.loads(str(requests.get(url,headers=headers).text))
    address = api_json['documents'][0]['address']
    crd = {"lat": str(address['y']), "lng": str(address['x'])}
    address_name = address['address_name']

    return crd

crd = get_location("제주 애월읍")
print(crd)
# Out:
# {'lat': '33.4621910539136', 'lng': '126.328972924341'}

# %%
df = pd.read_excel("./동대문구_초등학교.csv")
df
# Out:
#    학교종류명 설립구분   표준학교코드        학교명                               영문학교명  \
# 0   초등학교   사립  7021168   서울삼육초등학교    SEOUL SAHMYOOK ELEMENTARY SCHOOL
# 1   초등학교   사립  7021121     은석초등학교           Eunseok Elementary School
# 2   초등학교   공립  7021120   서울휘봉초등학교     Seoul Hwibong Elementary School
# 3   초등학교   공립  7021119   서울휘경초등학교    Seoul Hwykyung Elementary School
# 4   초등학교   공립  7021118   서울홍파초등학교      Seoul Hongpa Elementary School
# 5   초등학교   공립  7021117   서울홍릉초등학교   Seoul Hongneung Elementary School
# 6   초등학교   공립  7021116   서울청량초등학교  Seoul Chongryang Elementary School
# 7   초등학교   공립  7021110   서울종암초등학교      Seoul Jongam Elementary School
# 8   초등학교   공립  7021109   서울전동초등학교    Seoul Jeondong Elementary School
# 9   초등학교   공립  7021108   서울전농초등학교    Seoul Jeonnong Elementary School
# 10  초등학교   공립  7021107   서울전곡초등학교     Seoul Jeongok Elementary School
# 11  초등학교   공립  7021106   서울장평초등학교  Seoul Jangpyeong Elementary School
# 12  초등학교   공립  7021105   서울이문초등학교        Seoul Imun Elementary School
# 13  초등학교   공립  7021103   서울용두초등학교      Seoul Yongdu Elementary School
# 14  초등학교   공립  7021102   서울안평초등학교    Seoul Anpyeong Elementary School
# 15  초등학교   공립  7021099   서울신답초등학교      Seoul Sindab Elementary School
# 16  초등학교   공립  7021095   서울배봉초등학교     Seoul Baebong Elementary School
# 17  초등학교   공립  7021084   서울동답초등학교     Seoul Dongdap Elementary School
# 18  초등학교   공립  7021083  서울답십리초등학교    Seoul Dapsimni Elementary School
# 19  초등학교   공립  7021082   서울군자초등학교       Seoul Gunja Elementary School
# 20  초등학교   사립  7021079     경희초등학교          Kyunghee Elementary School
#
#            관할조직명  도로명우편번호                  도로명주소                도로명상세주소  \
# 0   서울특별시동부교육지원청     2458   서울특별시 동대문구 회기로10길 63       / 서울삼육초등학교 (회기동)
# 1   서울특별시동부교육지원청     2520   서울특별시 동대문구 장안벚꽃로 205          (장안동/ 은석초등학교)
# 2   서울특별시동부교육지원청     2511   서울특별시 동대문구 장안벚꽃로 309         (휘경동/서울휘봉초등학교)
# 3   서울특별시동부교육지원청     2495    서울특별시 동대문구 망우로6길 48        (휘경동/ 서울휘경초등학교)
# 4   서울특별시동부교육지원청     2479    서울특별시 동대문구 고산자로 518                  (제기동)
# 5   서울특별시동부교육지원청     2457      서울특별시 동대문구 회기로 90                 (청량리동)
# 6   서울특별시동부교육지원청     2452   서울특별시 동대문구 회기로25길 31         (회기동/서울청량초등학교)
# 7   서울특별시동부교육지원청     2574   서울특별시 동대문구 무학로44길 25                  (제기동)
# 8   서울특별시동부교육지원청     2508   서울특별시 동대문구 전농로16길 61       / 서울전동초등학교 (전농동)
# 9   서울특별시동부교육지원청     2541     서울특별시 동대문구 사가정로 66       / 서울전농초등학교 (전농동)
# 10  서울특별시동부교육지원청     2505     서울특별시 동대문구 전농로 172                  (전농동)
# 11  서울특별시동부교육지원청     2523        서울특별시 동대문구 답십리로         / 69길 27 (전농동)
# 12  서울특별시동부교육지원청     2411     서울특별시 동대문구 신이문로 16        (이문동/ 서울이문초등학교)
# 13  서울특별시동부교육지원청     2583  서울특별시 동대문구 천호대로13길 43                  (용두동)
# 14  서울특별시동부교육지원청     2641   서울특별시 동대문구 장한로14길 61       / 서울안평초등학교 (장안동)
# 15  서울특별시동부교육지원청     2592    서울특별시 동대문구 천호대로 177        (답십리동/서울신답초등학교)
# 16  서울특별시동부교육지원청     2509    서울특별시 동대문구 사가정로 193         / 배봉초등학교 (전농동)
# 17  서울특별시동부교육지원청     2609  서울특별시 동대문구 답십리로60길 12        (답십리동/서울동답초등학교)
# 18  서울특별시동부교육지원청     2601    서울특별시 동대문구 전농로3길 23     / 서울답십리초등학교 (답십리동)
# 19  서울특별시동부교육지원청     2632    서울특별시 동대문구 한천로6길 21       / 서울군자초등학교 (장안동)
# 20  서울특별시동부교육지원청     2447     서울특별시 동대문구 경희대로 26  / 경희초등학교 (회기동/ 경희대학교)
#
#             전화번호  ... 고등학교일반실업구분명 특수목적고등학교계열명 입시전후기구분명  주야구분명      설립일자  \
# 0    02-966-4859  ...         일반계         NaN       전기     주간  19190401
# 1   02-6937-8180  ...         일반계         NaN       전기     주간  19630328
# 2   02-2248-4644  ...        해당없음         NaN       전기     주간  20060301
# 3   02-2244-4941  ...         일반계         NaN       전기     주간  19591010
# 4    02-967-8161  ...         일반계         NaN       전기     주간  19590508
# 5    02-968-4701  ...         일반계         NaN       전기     주간  19670915
# 6    02-962-1341  ...         일반계         NaN       전기     주간  19370405
# 7    02-924-4125  ...         일반계         NaN       전기     주간  19220708
# 8   02-2214-6574  ...         일반계         NaN       전기     주간  19681206
# 9   02-2247-0291  ...         일반계         NaN       전기     주간  19420408
# 10  02-2242-6548  ...         일반계         NaN       전기     주간  19590508
# 11  02-2243-6108  ...         일반계         NaN       전기     주간  19800404
# 12   02-957-8141  ...         일반계         NaN       전기     주간  19670711
# 13   02-927-4892  ...         일반계         NaN       전기     주간  19481101
# 14  02-2214-0258  ...         일반계         NaN       전기     주간  19900716
# 15  02-2212-1485  ...         일반계         NaN       전기     주간  19710901
# 16  02-2243-6502  ...         일반계         NaN       전기     주간  19710105
# 17  02-2213-9820  ...         일반계         NaN       전기     주간  19831203
# 18  02-2242-9256  ...         일반계         NaN       전기     주간  19620201
# 19  02-2244-0488  ...         일반계         NaN       전기     주간  19730106
# 20   02-962-4300  ...         일반계         NaN       전기     주간  19610331
#
#        개교기념일  시도교육청코드    시도교육청명   소재지명      적재일시
# 0   19131001      B10  서울특별시교육청  서울특별시  20221225
# 1   19630416      B10  서울특별시교육청  서울특별시  20221225
# 2   20060510      B10  서울특별시교육청  서울특별시  20221225
# 3   19591010      B10  서울특별시교육청  서울특별시  20221225
# 4   19600705      B10  서울특별시교육청  서울특별시  20221225
# 5   19671130      B10  서울특별시교육청  서울특별시  20221225
# 6   19370405      B10  서울특별시교육청  서울특별시  20221225
# 7   19220708      B10  서울특별시교육청  서울특별시  20221225
# 8   19690520      B10  서울특별시교육청  서울특별시  20221225
# 9   19420408      B10  서울특별시교육청  서울특별시  20221225
# 10  19610406      B10  서울특별시교육청  서울특별시  20221225
# 11  19800404      B10  서울특별시교육청  서울특별시  20221225
# 12  19670906      B10  서울특별시교육청  서울특별시  20221225
# 13  19481101      B10  서울특별시교육청  서울특별시  20221225
# 14  19901010      B10  서울특별시교육청  서울특별시  20221225
# 15  19720509      B10  서울특별시교육청  서울특별시  20221225
# 16  19711008      B10  서울특별시교육청  서울특별시  20221225
# 17  19840523      B10  서울특별시교육청  서울특별시  20221225
# 18  19621129      B10  서울특별시교육청  서울특별시  20221225
# 19  19731122      B10  서울특별시교육청  서울특별시  20221225
# 20  19610518      B10  서울특별시교육청  서울특별시  20221225
#
# [21 rows x 25 columns]

# %%
def geocoding(df, count) :
    addr_list = []
    addr_list.append(df['도로명주소'])

    crd = []
    for i in addr_list :
        for n in range(count) : # crd 리스트 안에 좌표값 넣기
            print(n, '값을 넣었습니다.')
            try :
                crd.append(get_location(i[n]))
            except :
                crd.append({'lat' : '0', 'lng' : '0'})
    
    # 리스트에 lng, lat 값을 넣고 df에 추가
    lng_list = []
    lat_list = []
    for i in range(count) :
        lng_list.append(crd[i]['lng'])
        lat_list.append(crd[i]['lat'])

    df['lng'] = lng_list
    df['lat'] = lat_list

    df.to_csv("./20220801_단지_기본정보_좌표추가.csv", encoding='euckr')

# %%
geocoding(df, 21)
# Out:
# 0 값을 넣었습니다.
# 1 값을 넣었습니다.
# 2 값을 넣었습니다.
# 3 값을 넣었습니다.
# 4 값을 넣었습니다.
# 5 값을 넣었습니다.
# 6 값을 넣었습니다.
# 7 값을 넣었습니다.
# 8 값을 넣었습니다.
# 9 값을 넣었습니다.
# 10 값을 넣었습니다.
# 11 값을 넣었습니다.
# 12 값을 넣었습니다.
# 13 값을 넣었습니다.
# 14 값을 넣었습니다.
# 15 값을 넣었습니다.
# 16 값을 넣었습니다.
# 17 값을 넣었습니다.
# 18 값을 넣었습니다.
# 19 값을 넣었습니다.
# 20 값을 넣었습니다.
