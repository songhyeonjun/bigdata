# %% [markdown]
# # 1. 날짜 및 시간 자료형

# %% [markdown]
# ## datetime

# %%
from datetime import datetime

now = datetime.now()
now

# %%
now.year, now.month, now.day

# %%
delta = datetime(2022, 12, 31) - datetime.now()
delta
# Out:
# datetime.timedelta(days=143, seconds=61553, microseconds=598528)

# %%
delta.days, delta.seconds, delta.microseconds
# Out:
# (143, 61553, 598528)

# %%
from datetime import timedelta

now + timedelta(100)
# Out:
# datetime.datetime(2022, 11, 17, 6, 54, 6, 365634)

# %%
stamp = datetime(2022, 8, 5)
str(stamp)
# Out:
# '2022-08-05 00:00:00'

# %%
stamp.strftime('%Y-%m-%d')
# Out:
# '2022-08-05'

# %%
value = '2022-08-05'
datetime.strptime(value, '%Y-%m-%d')
# Out:
# datetime.datetime(2022, 8, 5, 0, 0)

# %% [markdown]
# ## parser

# %%
from dateutil.parser import parse

parse('2022-12-25')
# Out:
# datetime.datetime(2022, 12, 25, 0, 0)

# %%
parse('Jan 31, 2000 12:30 PM')
# Out:
# datetime.datetime(2000, 1, 31, 12, 30)

# %%
parse('6/12/2030', dayfirst = True)
# Out:
# datetime.datetime(2030, 12, 6, 0, 0)

# %% [markdown]
# ## to_datetime

# %%
import pandas as pd
datestrs = ['2020-07-06 12:00:00', '2025-07-06 08:00:00', '2031-07-06 00:00:00']
pd.to_datetime(datestrs)
# Out:
# DatetimeIndex(['2020-07-06 12:00:00', '2025-07-06 08:00:00',
#                '2031-07-06 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(datestrs + [None])
# Out:
# DatetimeIndex(['2020-07-06 12:00:00', '2025-07-06 08:00:00',
#                '2031-07-06 00:00:00', 'NaT'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## date_range

# %%
index = pd.date_range('2022-01-01', '2023-12-31')
index
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10',
#                ...
#                '2023-12-22', '2023-12-23', '2023-12-24', '2023-12-25',
#                '2023-12-26', '2023-12-27', '2023-12-28', '2023-12-29',
#                '2023-12-30', '2023-12-31'],
#               dtype='datetime64[ns]', length=730, freq='D')

# %%
pd.date_range(start = '2022-08-01', periods = 10)
# Out:
# DatetimeIndex(['2022-08-01', '2022-08-02', '2022-08-03', '2022-08-04',
#                '2022-08-05', '2022-08-06', '2022-08-07', '2022-08-08',
#                '2022-08-09', '2022-08-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(end = '2022-08-01', periods = 10)
# Out:
# DatetimeIndex(['2022-07-23', '2022-07-24', '2022-07-25', '2022-07-26',
#                '2022-07-27', '2022-07-28', '2022-07-29', '2022-07-30',
#                '2022-07-31', '2022-08-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2022-01-01', '2022-12-31', freq='BM')
# Out:
# DatetimeIndex(['2022-01-31', '2022-02-28', '2022-03-31', '2022-04-29',
#                '2022-05-31', '2022-06-30', '2022-07-29', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-30'],
#               dtype='datetime64[ns]', freq='BM')

# %%
pd.date_range('2022-02-03 03:04:34', periods = 5)
# Out:
# DatetimeIndex(['2022-02-03 03:04:34', '2022-02-04 03:04:34',
#                '2022-02-05 03:04:34', '2022-02-06 03:04:34',
#                '2022-02-07 03:04:34'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2022-02-03 03:04:34', periods = 5, normalize = True)
# Out:
# DatetimeIndex(['2022-02-03', '2022-02-04', '2022-02-05', '2022-02-06',
#                '2022-02-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2022-02-03', '2022-02-05 23:59', freq='8h')
# Out:
# DatetimeIndex(['2022-02-03 00:00:00', '2022-02-03 08:00:00',
#                '2022-02-03 16:00:00', '2022-02-04 00:00:00',
#                '2022-02-04 08:00:00', '2022-02-04 16:00:00',
#                '2022-02-05 00:00:00', '2022-02-05 08:00:00',
#                '2022-02-05 16:00:00'],
#               dtype='datetime64[ns]', freq='8H')

# %%
pd.date_range('2022-01-01', periods = 5, freq ='1h30min')
# Out:
# DatetimeIndex(['2022-01-01 00:00:00', '2022-01-01 01:30:00',
#                '2022-01-01 03:00:00', '2022-01-01 04:30:00',
#                '2022-01-01 06:00:00'],
#               dtype='datetime64[ns]', freq='90T')

# %%
range_data = pd.date_range('2022-01-01', '2022-08-01', freq = 'WOM-3WED')
list(range_data)
# Out:
# [Timestamp('2022-01-19 00:00:00', freq='WOM-3WED'),
#  Timestamp('2022-02-16 00:00:00', freq='WOM-3WED'),
#  Timestamp('2022-03-16 00:00:00', freq='WOM-3WED'),
#  Timestamp('2022-04-20 00:00:00', freq='WOM-3WED'),
#  Timestamp('2022-05-18 00:00:00', freq='WOM-3WED'),
#  Timestamp('2022-06-15 00:00:00', freq='WOM-3WED'),
#  Timestamp('2022-07-20 00:00:00', freq='WOM-3WED')]

# %% [markdown]
# ## to_period

# %%
index = pd.date_range('2022-01-01', '2023-12-31')
index
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10',
#                ...
#                '2023-12-22', '2023-12-23', '2023-12-24', '2023-12-25',
#                '2023-12-26', '2023-12-27', '2023-12-28', '2023-12-29',
#                '2023-12-30', '2023-12-31'],
#               dtype='datetime64[ns]', length=730, freq='D')

# %%
index2 = index.to_period()
index2
# Out:
# PeriodIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#              '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#              '2022-01-09', '2022-01-10',
#              ...
#              '2023-12-22', '2023-12-23', '2023-12-24', '2023-12-25',
#              '2023-12-26', '2023-12-27', '2023-12-28', '2023-12-29',
#              '2023-12-30', '2023-12-31'],
#             dtype='period[D]', length=730, freq='D')

# %% [markdown]
# # 2. 시계열 기초

# %%
# !conda install pandas-datareader
# !pip install yfinance

# %%
# https://finance.yahoo.com/
import pandas as pd
import numpy as np

import yfinance as yfin
from pandas_datareader import data

yfin.pdr_override()

df = data.get_data_yahoo('005930.KS', start = '2020-01-01', end = '2022-08-05')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2022-07-22', '2022-07-25', '2022-07-26', '2022-07-27',
#                '2022-07-28', '2022-07-29', '2022-08-01', '2022-08-02',
#                '2022-08-03', '2022-08-04'],
#               dtype='datetime64[ns]', name='Date', length=640, freq=None)

# %%
df[::2]
# Out:
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2020-01-02  55500.0  56000.0  55000.0  55200.0  51244.257812  12993228
# 2020-01-06  54900.0  55600.0  54600.0  55500.0  51522.753906  10278951
# 2020-01-08  56200.0  57400.0  55900.0  56800.0  52729.597656  23501171
# 2020-01-10  58800.0  59700.0  58300.0  59500.0  55236.105469  16000170
# 2020-01-14  60400.0  61000.0  59900.0  60000.0  55700.277344  16906295
# ...             ...      ...      ...      ...           ...       ...
# 2022-07-22  61800.0  62200.0  61200.0  61300.0  61300.000000  10261310
# 2022-07-26  60800.0  61900.0  60800.0  61700.0  61700.000000   6597211
# 2022-07-28  62300.0  62600.0  61600.0  61900.0  61900.000000  10745302
# 2022-08-01  61000.0  61700.0  60300.0  61300.0  61300.000000  13154816
# 2022-08-03  61600.0  61600.0  61000.0  61300.0  61300.000000  10053861
#
# [320 rows x 6 columns]

# %%
df.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
df.index[0]
# Out:
# Timestamp('2020-01-02 00:00:00')

# %%
stamp = df.index[2]

# %% [markdown]
# ## 월 선택

# %%
df['2022-03']
# Out:
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2022-03-02  72300.0  72400.0  71500.0  71700.0  70897.773438  12481430
# 2022-03-03  72300.0  73100.0  72200.0  72900.0  72084.351562  13232638
# 2022-03-04  72900.0  72900.0  72900.0  72900.0  72084.351562         0
# 2022-03-07  70000.0  70600.0  69900.0  70100.0  69315.679688  18617138
# 2022-03-08  68800.0  70000.0  68700.0  69500.0  68722.390625  15828269
# 2022-03-10  69500.0  69500.0  69500.0  69500.0  68722.390625         0
# 2022-03-11  70500.0  70700.0  69700.0  70000.0  69216.796875  15787655
# 2022-03-14  70000.0  70200.0  69600.0  70200.0  69414.554688   9040993
# 2022-03-15  70200.0  70200.0  70200.0  70200.0  69414.554688         0
# 2022-03-16  70200.0  70500.0  69700.0  70400.0  69612.312500  10175750
# 2022-03-17  70400.0  70400.0  70400.0  70400.0  69612.312500         0
# 2022-03-18  70600.0  70900.0  70200.0  70700.0  69908.960938  14410038
# ...

# %%
df.loc['2022-05']
# Out:
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2022-05-02  66600.0  67600.0  66500.0  67300.0  66890.984375  14106184
# 2022-05-03  67400.0  68400.0  67300.0  67500.0  67089.773438  14168875
# 2022-05-04  68000.0  68400.0  67500.0  67900.0  67487.343750  11505248
# 2022-05-06  67000.0  67100.0  66500.0  66500.0  66095.851562  14356156
# 2022-05-10  65900.0  66300.0  65300.0  65700.0  65300.710938  17235605
# 2022-05-11  65500.0  66300.0  65200.0  65700.0  65300.710938  12330920
# 2022-05-12  65200.0  65500.0  64900.0  64900.0  64505.574219  16414188
# 2022-05-13  65300.0  66700.0  65200.0  66500.0  66095.851562  14551536
# 2022-05-16  67100.0  67400.0  66100.0  66300.0  65897.062500  11937555
# 2022-05-17  66600.0  67900.0  66600.0  67600.0  67189.164062  15680447
# 2022-05-18  68300.0  68700.0  67600.0  68100.0  67686.125000  16486319
# 2022-05-19  66500.0  67600.0  66500.0  67500.0  67089.773438  17073727
# ...

# %% [markdown]
# ## 기간 선택

# %% [markdown]
# ### datetime index

# %%
from datetime import datetime
df[datetime(2022, 8, 1):]
# Out:
#                Open     High      Low    Close  Adj Close    Volume
# Date
# 2022-08-01  61000.0  61700.0  60300.0  61300.0    61300.0  13154816
# 2022-08-02  61200.0  61900.0  61000.0  61700.0    61700.0  13614895
# 2022-08-03  61600.0  61600.0  61000.0  61300.0    61300.0  10053861
# 2022-08-04  61700.0  61800.0  61200.0  61500.0    61500.0   9125439

# %% [markdown]
# ### string index

# %%
df['2022-07-01' : '2022-07-10']
# Out:
#                Open     High      Low    Close  Adj Close    Volume
# Date
# 2022-07-01  56900.0  57500.0  55900.0  56200.0    56200.0  24982097
# 2022-07-04  56100.0  57400.0  55700.0  57100.0    57100.0  17807126
# 2022-07-05  57600.0  58200.0  57200.0  57200.0    57200.0  14216539
# 2022-07-06  57300.0  57300.0  56400.0  56400.0    56400.0  16820461
# 2022-07-07  56400.0  58700.0  56300.0  58200.0    58200.0  21322833
# 2022-07-08  58600.0  59300.0  58200.0  58700.0    58700.0  15339271

# %% [markdown]
# ### truncate

# %%
df.truncate(after = '2022-01-31')
# Out:
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2020-01-02  55500.0  56000.0  55000.0  55200.0  51244.257812  12993228
# 2020-01-03  56000.0  56600.0  54900.0  55500.0  51522.753906  15422255
# 2020-01-06  54900.0  55600.0  54600.0  55500.0  51522.753906  10278951
# 2020-01-07  55700.0  56400.0  55600.0  55800.0  51801.257812  10009778
# 2020-01-08  56200.0  57400.0  55900.0  56800.0  52729.597656  23501171
# ...             ...      ...      ...      ...           ...       ...
# 2022-01-24  75400.0  75800.0  74700.0  75100.0  74259.734375  13691134
# 2022-01-25  74800.0  75000.0  73200.0  74000.0  73172.039062  17766704
# 2022-01-26  74000.0  74000.0  74000.0  74000.0  73172.039062         0
# 2022-01-27  73800.0  74000.0  71300.0  71300.0  70502.250000  22274777
# 2022-01-28  71300.0  73700.0  71200.0  73300.0  72479.867188  21367447
#
# [515 rows x 6 columns]

# %% [markdown]
# ## 이동

# %%
df.shift(2)
# Out:
#                Open     High      Low    Close     Adj Close      Volume
# Date
# 2020-01-02      NaN      NaN      NaN      NaN           NaN         NaN
# 2020-01-03      NaN      NaN      NaN      NaN           NaN         NaN
# 2020-01-06  55500.0  56000.0  55000.0  55200.0  51244.257812  12993228.0
# 2020-01-07  56000.0  56600.0  54900.0  55500.0  51522.753906  15422255.0
# 2020-01-08  54900.0  55600.0  54600.0  55500.0  51522.753906  10278951.0
# ...             ...      ...      ...      ...           ...         ...
# 2022-07-29  61300.0  61900.0  61200.0  61800.0  61800.000000   7320997.0
# 2022-08-01  62300.0  62600.0  61600.0  61900.0  61900.000000  10745302.0
# 2022-08-02  62400.0  62600.0  61300.0  61400.0  61400.000000  15093120.0
# 2022-08-03  61000.0  61700.0  60300.0  61300.0  61300.000000  13154816.0
# 2022-08-04  61200.0  61900.0  61000.0  61700.0  61700.000000  13614895.0
#
# [640 rows x 6 columns]

# %%
df.shift(-2)
# Out:
#                Open     High      Low    Close     Adj Close      Volume
# Date
# 2020-01-02  54900.0  55600.0  54600.0  55500.0  51522.753906  10278951.0
# 2020-01-03  55700.0  56400.0  55600.0  55800.0  51801.257812  10009778.0
# 2020-01-06  56200.0  57400.0  55900.0  56800.0  52729.597656  23501171.0
# 2020-01-07  58400.0  58600.0  57400.0  58600.0  54400.601562  24102579.0
# 2020-01-08  58800.0  59700.0  58300.0  59500.0  55236.105469  16000170.0
# ...             ...      ...      ...      ...           ...         ...
# 2022-07-29  61200.0  61900.0  61000.0  61700.0  61700.000000  13614895.0
# 2022-08-01  61600.0  61600.0  61000.0  61300.0  61300.000000  10053861.0
# 2022-08-02  61700.0  61800.0  61200.0  61500.0  61500.000000   9125439.0
# 2022-08-03      NaN      NaN      NaN      NaN           NaN         NaN
# 2022-08-04      NaN      NaN      NaN      NaN           NaN         NaN
#
# [640 rows x 6 columns]

# %%
df.shift(2, freq='M')
# Out:
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2020-02-29  55500.0  56000.0  55000.0  55200.0  51244.257812  12993228
# 2020-02-29  56000.0  56600.0  54900.0  55500.0  51522.753906  15422255
# 2020-02-29  54900.0  55600.0  54600.0  55500.0  51522.753906  10278951
# 2020-02-29  55700.0  56400.0  55600.0  55800.0  51801.257812  10009778
# 2020-02-29  56200.0  57400.0  55900.0  56800.0  52729.597656  23501171
# ...             ...      ...      ...      ...           ...       ...
# 2022-08-31  62400.0  62600.0  61300.0  61400.0  61400.000000  15093120
# 2022-09-30  61000.0  61700.0  60300.0  61300.0  61300.000000  13154816
# 2022-09-30  61200.0  61900.0  61000.0  61700.0  61700.000000  13614895
# 2022-09-30  61600.0  61600.0  61000.0  61300.0  61300.000000  10053861
# 2022-09-30  61700.0  61800.0  61200.0  61500.0  61500.000000   9125439
#
# [640 rows x 6 columns]

# %%
df.shift(2, freq='D')
# Out:
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2020-01-04  55500.0  56000.0  55000.0  55200.0  51244.257812  12993228
# 2020-01-05  56000.0  56600.0  54900.0  55500.0  51522.753906  15422255
# 2020-01-08  54900.0  55600.0  54600.0  55500.0  51522.753906  10278951
# 2020-01-09  55700.0  56400.0  55600.0  55800.0  51801.257812  10009778
# 2020-01-10  56200.0  57400.0  55900.0  56800.0  52729.597656  23501171
# ...             ...      ...      ...      ...           ...       ...
# 2022-07-31  62400.0  62600.0  61300.0  61400.0  61400.000000  15093120
# 2022-08-03  61000.0  61700.0  60300.0  61300.0  61300.000000  13154816
# 2022-08-04  61200.0  61900.0  61000.0  61700.0  61700.000000  13614895
# 2022-08-05  61600.0  61600.0  61000.0  61300.0  61300.000000  10053861
# 2022-08-06  61700.0  61800.0  61200.0  61500.0  61500.000000   9125439
#
# [640 rows x 6 columns]

# %%
df.shift(2, freq='90T')
# Out:
#                         Open     High      Low    Close     Adj Close  \
# Date
# 2020-01-02 03:00:00  55500.0  56000.0  55000.0  55200.0  51244.257812
# 2020-01-03 03:00:00  56000.0  56600.0  54900.0  55500.0  51522.753906
# 2020-01-06 03:00:00  54900.0  55600.0  54600.0  55500.0  51522.753906
# 2020-01-07 03:00:00  55700.0  56400.0  55600.0  55800.0  51801.257812
# 2020-01-08 03:00:00  56200.0  57400.0  55900.0  56800.0  52729.597656
# ...                      ...      ...      ...      ...           ...
# 2022-07-29 03:00:00  62400.0  62600.0  61300.0  61400.0  61400.000000
# 2022-08-01 03:00:00  61000.0  61700.0  60300.0  61300.0  61300.000000
# 2022-08-02 03:00:00  61200.0  61900.0  61000.0  61700.0  61700.000000
# 2022-08-03 03:00:00  61600.0  61600.0  61000.0  61300.0  61300.000000
# 2022-08-04 03:00:00  61700.0  61800.0  61200.0  61500.0  61500.000000
#
#                        Volume
# Date
# 2020-01-02 03:00:00  12993228
# 2020-01-03 03:00:00  15422255
# ...

# %% [markdown]
# ## 기간 연산

# %% [markdown]
# ### 월말 선택

# %%
df.asfreq('M', how = 'start')
# Out:
#                Open     High      Low    Close     Adj Close      Volume
# Date
# 2020-01-31  57800.0  58400.0  56400.0  56400.0  52358.257812  19749457.0
# 2020-02-29      NaN      NaN      NaN      NaN           NaN         NaN
# 2020-03-31  48000.0  48500.0  47150.0  47750.0  44655.425781  30654261.0
# 2020-04-30      NaN      NaN      NaN      NaN           NaN         NaN
# 2020-05-31      NaN      NaN      NaN      NaN           NaN         NaN
# 2020-06-30  53900.0  53900.0  52800.0  52800.0  49708.289062  21157172.0
# 2020-07-31  59500.0  59600.0  57700.0  57900.0  54509.656250  21943345.0
# 2020-08-31  56000.0  56100.0  54000.0  54000.0  50838.023438  32671367.0
# 2020-09-30      NaN      NaN      NaN      NaN           NaN         NaN
# 2020-10-31      NaN      NaN      NaN      NaN           NaN         NaN
# 2020-11-30  68400.0  68600.0  66700.0  66700.0  63180.656250  43811016.0
# 2020-12-31      NaN      NaN      NaN      NaN           NaN         NaN
# ...

# %%
df.asfreq('B', how = 'end')
# Out:
#                Open     High      Low    Close     Adj Close      Volume
# Date
# 2020-01-02  55500.0  56000.0  55000.0  55200.0  51244.257812  12993228.0
# 2020-01-03  56000.0  56600.0  54900.0  55500.0  51522.753906  15422255.0
# 2020-01-06  54900.0  55600.0  54600.0  55500.0  51522.753906  10278951.0
# 2020-01-07  55700.0  56400.0  55600.0  55800.0  51801.257812  10009778.0
# 2020-01-08  56200.0  57400.0  55900.0  56800.0  52729.597656  23501171.0
# ...             ...      ...      ...      ...           ...         ...
# 2022-07-29  62400.0  62600.0  61300.0  61400.0  61400.000000  15093120.0
# 2022-08-01  61000.0  61700.0  60300.0  61300.0  61300.000000  13154816.0
# 2022-08-02  61200.0  61900.0  61000.0  61700.0  61700.000000  13614895.0
# 2022-08-03  61600.0  61600.0  61000.0  61300.0  61300.000000  10053861.0
# 2022-08-04  61700.0  61800.0  61200.0  61500.0  61500.000000   9125439.0
#
# [676 rows x 6 columns]

# %% [markdown]
# ## 리샘플링

# %%
df.resample('M').mean()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-01-31  58870.000000  59475.000000  58195.000000  58815.000000
# 2020-02-29  58890.000000  59675.000000  58330.000000  59085.000000
# 2020-03-31  50381.818182  51440.909091  49325.000000  50331.818182
# 2020-04-30  49127.500000  49567.500000  48445.000000  49045.000000
# 2020-05-31  49071.052632  49476.315789  48626.315789  49100.000000
# 2020-06-30  52950.000000  53768.181818  52218.181818  52986.363636
# 2020-07-31  54930.434783  55356.521739  54256.521739  54726.086957
# 2020-08-31  57360.000000  57865.000000  56600.000000  56980.000000
# 2020-09-30  58176.190476  58761.904762  57709.523810  58176.190476
# 2020-10-31  59836.842105  60242.105263  59263.157895  59736.842105
# 2020-11-30  63090.476190  64019.047619  62476.190476  63419.047619
# 2020-12-31  73066.666667  74233.333333  72600.000000  73619.047619
# 2021-01-31  86365.000000  88410.000000  85190.000000  86565.000000
# ...

# %%
df.resample('M', kind='period').mean()
# Out:
#                  Open          High           Low         Close     Adj Close  \
# Date
# 2020-01  58870.000000  59475.000000  58195.000000  58815.000000  54600.195703
# 2020-02  58890.000000  59675.000000  58330.000000  59085.000000  54850.847852
# 2020-03  50381.818182  51440.909091  49325.000000  50331.818182  46754.722124
# 2020-04  49127.500000  49567.500000  48445.000000  49045.000000  45866.498633
# 2020-05  49071.052632  49476.315789  48626.315789  49100.000000  45917.934622
# 2020-06  52950.000000  53768.181818  52218.181818  52986.363636  49582.329368
# 2020-07  54930.434783  55356.521739  54256.521739  54726.086957  51521.593750
# 2020-08  57360.000000  57865.000000  56600.000000  56980.000000  53643.529102
# 2020-09  58176.190476  58761.904762  57709.523810  58176.190476  54801.776042
# 2020-10  59836.842105  60242.105263  59263.157895  59736.842105  56584.902549
# 2020-11  63090.476190  64019.047619  62476.190476  63419.047619  60072.822173
# ...

# %%
ts = pd.Series(np.arange(12), 
               index = pd.date_range('2020-01-01', periods = 12, freq='T'))
ts
# Out:
# 2020-01-01 00:00:00     0
# 2020-01-01 00:01:00     1
# 2020-01-01 00:02:00     2
# 2020-01-01 00:03:00     3
# 2020-01-01 00:04:00     4
# 2020-01-01 00:05:00     5
# 2020-01-01 00:06:00     6
# 2020-01-01 00:07:00     7
# 2020-01-01 00:08:00     8
# 2020-01-01 00:09:00     9
# 2020-01-01 00:10:00    10
# 2020-01-01 00:11:00    11
# Freq: T, dtype: int32

# %%
ts.resample('5min', closed='right').mean()
# Out:
# 2019-12-31 23:55:00     0
# 2020-01-01 00:00:00     3
# 2020-01-01 00:05:00     8
# 2020-01-01 00:10:00    11
# Freq: 5T, dtype: int32

# %%
ts.resample('5min', closed='left').mean()
# Out:
# 2020-01-01 00:00:00     2.0
# 2020-01-01 00:05:00     7.0
# 2020-01-01 00:10:00    10.5
# Freq: 5T, dtype: float64

# %%
df.resample('D').asfreq()
# Out:
#                Open     High      Low    Close     Adj Close      Volume
# Date
# 2020-01-02  55500.0  56000.0  55000.0  55200.0  51244.257812  12993228.0
# 2020-01-03  56000.0  56600.0  54900.0  55500.0  51522.753906  15422255.0
# 2020-01-04      NaN      NaN      NaN      NaN           NaN         NaN
# 2020-01-05      NaN      NaN      NaN      NaN           NaN         NaN
# 2020-01-06  54900.0  55600.0  54600.0  55500.0  51522.753906  10278951.0
# ...             ...      ...      ...      ...           ...         ...
# 2022-07-31      NaN      NaN      NaN      NaN           NaN         NaN
# 2022-08-01  61000.0  61700.0  60300.0  61300.0  61300.000000  13154816.0
# 2022-08-02  61200.0  61900.0  61000.0  61700.0  61700.000000  13614895.0
# 2022-08-03  61600.0  61600.0  61000.0  61300.0  61300.000000  10053861.0
# 2022-08-04  61700.0  61800.0  61200.0  61500.0  61500.000000   9125439.0
#
# [946 rows x 6 columns]

# %%
df.resample('D').ffill()
# Out:
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2020-01-02  55500.0  56000.0  55000.0  55200.0  51244.257812  12993228
# 2020-01-03  56000.0  56600.0  54900.0  55500.0  51522.753906  15422255
# 2020-01-04  56000.0  56600.0  54900.0  55500.0  51522.753906  15422255
# 2020-01-05  56000.0  56600.0  54900.0  55500.0  51522.753906  15422255
# 2020-01-06  54900.0  55600.0  54600.0  55500.0  51522.753906  10278951
# ...             ...      ...      ...      ...           ...       ...
# 2022-07-31  62400.0  62600.0  61300.0  61400.0  61400.000000  15093120
# 2022-08-01  61000.0  61700.0  60300.0  61300.0  61300.000000  13154816
# 2022-08-02  61200.0  61900.0  61000.0  61700.0  61700.000000  13614895
# 2022-08-03  61600.0  61600.0  61000.0  61300.0  61300.000000  10053861
# 2022-08-04  61700.0  61800.0  61200.0  61500.0  61500.000000   9125439
#
# [946 rows x 6 columns]

# %% [markdown]
# ## 이동창 함수

# %%
df.resample('B').ffill()
# Out:
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2020-01-02  55500.0  56000.0  55000.0  55200.0  51244.257812  12993228
# 2020-01-03  56000.0  56600.0  54900.0  55500.0  51522.753906  15422255
# 2020-01-06  54900.0  55600.0  54600.0  55500.0  51522.753906  10278951
# 2020-01-07  55700.0  56400.0  55600.0  55800.0  51801.257812  10009778
# 2020-01-08  56200.0  57400.0  55900.0  56800.0  52729.597656  23501171
# ...             ...      ...      ...      ...           ...       ...
# 2022-07-29  62400.0  62600.0  61300.0  61400.0  61400.000000  15093120
# 2022-08-01  61000.0  61700.0  60300.0  61300.0  61300.000000  13154816
# 2022-08-02  61200.0  61900.0  61000.0  61700.0  61700.000000  13614895
# 2022-08-03  61600.0  61600.0  61000.0  61300.0  61300.000000  10053861
# 2022-08-04  61700.0  61800.0  61200.0  61500.0  61500.000000   9125439
#
# [676 rows x 6 columns]

# %%
df['Close'].rolling(10).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Close'].rolling(10).mean()
# Out:
# Date
# 2020-01-02        NaN
# 2020-01-03        NaN
# 2020-01-06        NaN
# 2020-01-07        NaN
# 2020-01-08        NaN
#                ...
# 2022-07-29    61430.0
# 2022-08-01    61370.0
# 2022-08-02    61450.0
# 2022-08-03    61530.0
# 2022-08-04    61500.0
# Name: Close, Length: 640, dtype: float64

# %%
df['Close'].rolling(10, min_periods=2).mean()
# Out:
# Date
# 2020-01-02        NaN
# 2020-01-03    55350.0
# 2020-01-06    55400.0
# 2020-01-07    55500.0
# 2020-01-08    55760.0
#                ...
# 2022-07-29    61430.0
# 2022-08-01    61370.0
# 2022-08-02    61450.0
# 2022-08-03    61530.0
# 2022-08-04    61500.0
# Name: Close, Length: 640, dtype: float64

# %%
df_std = df['Close'].rolling(10, min_periods=2).std()
df_std.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Close'].pct_change()
# Out:
# Date
# 2020-01-02         NaN
# 2020-01-03    0.005435
# 2020-01-06    0.000000
# 2020-01-07    0.005405
# 2020-01-08    0.017921
#                 ...
# 2022-07-29   -0.008078
# 2022-08-01   -0.001629
# 2022-08-02    0.006525
# 2022-08-03   -0.006483
# 2022-08-04    0.003263
# Name: Close, Length: 640, dtype: float64
